# %%
import pandas as pd

# %% [markdown]
# # 1. Data Loading

# %%
na_values = ["NA", "Missing"]
df = pd.read_csv("data/survey_results_public.csv", index_col="Respondent", na_values=na_values)
schema_df = pd.read_csv("data/survey_results_schema.csv", index_col="Column", na_values=na_values)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
#
# ...

# %%
df.describe()
# Out:
#                 Age      CompTotal  ConvertedComp   WorkWeekHrs
# count  45446.000000   3.482600e+04   3.475600e+04  41151.000000
# mean      30.834111  3.190464e+242   1.037561e+05     40.782174
# std        9.585392            inf   2.268853e+05     17.816383
# min        1.000000   0.000000e+00   0.000000e+00      1.000000
# 25%       24.000000   2.000000e+04   2.464800e+04     40.000000
# 50%       29.000000   6.300000e+04   5.404900e+04     40.000000
# 75%       35.000000   1.250000e+05   9.500000e+04     44.000000
# max      279.000000  1.111111e+247   2.000000e+06    475.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Respondent                    64461 non-null  int64
#  1   MainBranch                    64162 non-null  object
#  2   Hobbyist                      64416 non-null  object
#  3   Age                           45446 non-null  float64
#  4   Age1stCode                    57900 non-null  object
#  5   CompFreq                      40069 non-null  object
#  6   CompTotal                     34826 non-null  float64
#  7   ConvertedComp                 34756 non-null  float64
#  8   Country                       64072 non-null  object
#  9   CurrencyDesc                  45472 non-null  object
#  10  CurrencySymbol                45472 non-null  object
#  11  DatabaseDesireNextYear        44070 non-null  object
# ...

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
#
# ...

# %%
df.shape
# Out:
# (64461, 60)

# %%
schema_df
# Out:
#                                                          QuestionText
# Column
# Respondent          Randomized respondent ID number (not in order ...
# MainBranch          Which of the following options best describes ...
# Hobbyist                                      Do you code as a hobby?
# Age                 What is your age (in years)? If you prefer not...
# Age1stCode          At what age did you write your first line of c...
# ...                                                               ...
# WebframeWorkedWith  Which web frameworks have you done extensive d...
# WelcomeChange       Compared to last year, how welcome do you feel...
# WorkWeekHrs         On average, how many hours per week do you wor...
# YearsCode           Including any education, how many years have y...
# YearsCodePro        NOT including education, how many years have y...
#
# [61 rows x 1 columns]

# %%
schema_df.shape
# Out:
# (61, 1)

# %% [markdown]
# # 2. Selecting Rows and Columns

# %%
df["Hobbyist"]
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3        Yes
# 4        Yes
#         ...
# 64456    Yes
# 64457    Yes
# 64458    Yes
# 64459    Yes
# 64460    Yes
# Name: Hobbyist, Length: 64461, dtype: object

# %%
df.loc[2, "Hobbyist"]
# Out:
# 'Yes'

# %%
df.loc[0:3, "Hobbyist":"Employment"]
# Out:
#   Hobbyist   Age Age1stCode CompFreq  CompTotal  ConvertedComp  \
# 0      Yes   NaN         13  Monthly        NaN            NaN
# 1       No   NaN         19      NaN        NaN            NaN
# 2      Yes   NaN         15      NaN        NaN            NaN
# 3      Yes  25.0         18      NaN        NaN            NaN
#
#               Country    CurrencyDesc CurrencySymbol DatabaseDesireNextYear  \
# 0             Germany   European Euro            EUR   Microsoft SQL Server
# 1      United Kingdom  Pound sterling            GBP                    NaN
# 2  Russian Federation             NaN            NaN                    NaN
# 3             Albania    Albanian lek            ALL                    NaN
#
#                           DatabaseWorkedWith  \
# 0  Elasticsearch;Microsoft SQL Server;Oracle
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
#
# ...

# %% [markdown]
# # 3. Set, Reset, and Use Indexes

# %%
schema_df.loc["Hobbyist"]
# Out:
# QuestionText    Do you code as a hobby?
# Name: Hobbyist, dtype: object

# %%
schema_df.sort_index(inplace=True)
schema_df
# Out:
#                                                          QuestionText
# Column
# Age                 What is your age (in years)? If you prefer not...
# Age1stCode          At what age did you write your first line of c...
# CompFreq             Is that compensation weekly, monthly, or yearly?
# CompTotal           What is your current total compensation (salar...
# ConvertedComp       Salary converted to annual USD salaries using ...
# ...                                                               ...
# WebframeWorkedWith  Which web frameworks have you done extensive d...
# WelcomeChange       Compared to last year, how welcome do you feel...
# WorkWeekHrs         On average, how many hours per week do you wor...
# YearsCode           Including any education, how many years have y...
# YearsCodePro        NOT including education, how many years have y...
#
# [61 rows x 1 columns]

# %% [markdown]
# # 4. Using Conditionals to Filter Rows and Columns

# %%
high_salary = (df["ConvertedComp"] > 70000)

# %%
df.loc[high_salary, ["Country", "LanguageWorkedWith", "ConvertedComp"]]
# Out:
#                    Country                                 LanguageWorkedWith  \
# Respondent
# 8            United States                                         Python;SQL
# 16          United Kingdom  Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# 17           United States              C#;HTML/CSS;JavaScript;Python;SQL;VBA
# 18           United States                Bash/Shell/PowerShell;HTML/CSS;Perl
# 19           United States  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;S...
# ...                    ...                                                ...
# 65586        United States                                                NaN
# 65589        United States                                                NaN
# 65602        United States                                                NaN
# 65604        United States                                                NaN
# 65617              Germany                                                NaN
#
# ...

# %%
countries = ["United States", "United Kingdom", "India", "Canada", "Germany"]
filt = df["Country"].isin(countries)

# %%
df.loc[filt, "Country"]
# Out:
# Respondent
# 1               Germany
# 2        United Kingdom
# 5         United States
# 6               Germany
# 7                 India
#               ...
# 62834            Canada
# 62954             India
# 63077     United States
# 64236             India
# 64858     United States
# Name: Country, Length: 30849, dtype: object

# %%
filt = df["LanguageWorkedWith"].str.contains("Python", na=False)

# %%
df.loc[filt, "LanguageWorkedWith"]
# Out:
# Respondent
# 3                                 Objective-C;Python;Swift
# 8                                               Python;SQL
# 10                     HTML/CSS;Java;JavaScript;Python;SQL
# 13                                     C;JavaScript;Python
# 15        Bash/Shell/PowerShell;C;HTML/CSS;Java;Python;SQL
#                                ...
# 61561    Bash/Shell/PowerShell;HTML/CSS;JavaScript;Perl...
# 62391       C++;HTML/CSS;JavaScript;Python;Ruby;TypeScript
# 63077              C++;HTML/CSS;Java;JavaScript;Python;SQL
# 63640    Bash/Shell/PowerShell;C;C#;C++;HTML/CSS;Java;J...
# 64867    Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# Name: LanguageWorkedWith, Length: 25287, dtype: object

# %% [markdown]
# # 5. Updating Rows and Columns - Modifying Data Within DataFrames

# %%
pd.set_option("display.max_columns", 85)
pd.set_option("display.max_rows", 85)

# %%
df.rename(columns={"ConvertedComp": "SalaryUSD"}, inplace=True)

# %%
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN      Yes   NaN
# 64867                                                     NaN      Yes   NaN
# 64898                                                     NaN      Yes   NaN
# 64925                                                     NaN      Yes   NaN
# 65112                                                     NaN      Yes   NaN
#
# ...

# %%
df["Hobbyist"]
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4        Yes
# 5        Yes
#         ...
# 64858    Yes
# 64867    Yes
# 64898    Yes
# 64925    Yes
# 65112    Yes
# Name: Hobbyist, Length: 64461, dtype: object

# %%
df["Hobbyist"].replace({"Yes": True, "No": False}, inplace=True)

# %%
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession     True   NaN
# 2                              I am a developer by profession    False   NaN
# 3                                 I code primarily as a hobby     True   NaN
# 4                              I am a developer by profession     True  25.0
# 5           I used to be a developer by profession, but no...     True  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN     True   NaN
# 64867                                                     NaN     True   NaN
# 64898                                                     NaN     True   NaN
# 64925                                                     NaN     True   NaN
# 65112                                                     NaN     True   NaN
#
# ...

# %% [markdown]
# # 6. Add Remove Rows and Columns From DataFrames

# %% [markdown]
# # 7. Sorting Data

# %%
df.sort_values(by=["Country", "ConvertedComp"], ascending=[True, False], inplace=True)

# %%
df[["Country", "ConvertedComp"]]
# Out:
#                 Country  ConvertedComp
# Respondent
# 62788       Afghanistan      1000000.0
# 65381       Afghanistan      1000000.0
# 65456       Afghanistan      1000000.0
# 38672       Afghanistan       231192.0
# 28374       Afghanistan       130000.0
# ...                 ...            ...
# 60055               NaN            NaN
# 61121               NaN            NaN
# 61570               NaN            NaN
# 61918               NaN            NaN
# 62605               NaN            NaN
#
# [64461 rows x 2 columns]

# %%
df["ConvertedComp"].nlargest(10)
# Out:
# Respondent
# 5725     2000000.0
# 54263    2000000.0
# 43430    2000000.0
# 59279    2000000.0
# 46711    2000000.0
# 123      2000000.0
# 125      2000000.0
# 193      2000000.0
# 665      2000000.0
# 699      2000000.0
# Name: ConvertedComp, dtype: float64

# %%
df.nlargest(10, "ConvertedComp")
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 5725                           I am a developer by profession       No  26.0
# 54263                          I am a developer by profession      Yes  29.0
# 43430                          I am a developer by profession      Yes  33.0
# 59279                          I am a developer by profession      Yes   NaN
# 46711                          I am a developer by profession      Yes   NaN
# 123                            I am a developer by profession      Yes  26.0
# 125         I am not primarily a developer, but I write co...      Yes  41.0
# 193                            I am a developer by profession      Yes  29.0
# 665                            I am a developer by profession      Yes  24.0
# 699         I am not primarily a developer, but I write co...      Yes  39.0
#
#                       Age1stCode CompFreq     CompTotal  ConvertedComp  \
# Respondent
# ...

# %% [markdown]
# # 8. Grouping and Aggregating

# %%
df.head()
# Out:
#                                 MainBranch Hobbyist  Age  \
# Respondent
# 62788       I am a developer by profession      Yes  NaN
# 65381       I am a developer by profession       No  NaN
# 65456       I am a developer by profession      Yes  NaN
# 38672       I am a developer by profession       No  NaN
# 28374       I am a developer by profession      Yes  NaN
#
#                       Age1stCode CompFreq     CompTotal  ConvertedComp  \
# Respondent
# 62788                        NaN   Weekly  8.000000e+06      1000000.0
# 65381                          8   Weekly  8.740000e+09      1000000.0
# 65456       Younger than 5 years   Weekly  5.521171e+09      1000000.0
# 38672                          5  Monthly  1.225000e+06       231192.0
# 28374                          7   Yearly  1.300000e+05       130000.0
#
#                 Country          CurrencyDesc CurrencySymbol  ...  \
# Respondent                                                    ...
# ...

# %%
df["ConvertedComp"].median()
# Out:
# 54049.0

# %%
df.median()
# Out:
# Age                 29.0
# CompTotal        63000.0
# ConvertedComp    54049.0
# WorkWeekHrs         40.0
# dtype: float64

# %%
df.describe()
# Out:
#                 Age      CompTotal  ConvertedComp   WorkWeekHrs
# count  45446.000000   3.482600e+04   3.475600e+04  41151.000000
# mean      30.834111  3.190464e+242   1.037561e+05     40.782174
# std        9.585392            inf   2.268853e+05     17.816383
# min        1.000000   0.000000e+00   0.000000e+00      1.000000
# 25%       24.000000   2.000000e+04   2.464800e+04     40.000000
# 50%       29.000000   6.300000e+04   5.404900e+04     40.000000
# 75%       35.000000   1.250000e+05   9.500000e+04     44.000000
# max      279.000000  1.111111e+247   2.000000e+06    475.000000

# %%
df["ConvertedComp"].count()
# Out:
# 34756

# %%
df["Hobbyist"]
# Out:
# Respondent
# 62788    Yes
# 65381     No
# 65456    Yes
# 38672     No
# 28374    Yes
#         ...
# 60055     No
# 61121    Yes
# 61570     No
# 61918    Yes
# 62605     No
# Name: Hobbyist, Length: 64461, dtype: object

# %%
df["Hobbyist"].value_counts()
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %%
df["WorkWeekHrs"].value_counts(normalize=True)
# Out:
# 40.00     0.468810
# 45.00     0.092027
# 50.00     0.066754
# 35.00     0.048601
# 38.00     0.032855
#             ...
# 115.00    0.000024
# 144.00    0.000024
# 408.00    0.000024
# 37.22     0.000024
# 83.00     0.000024
# Name: WorkWeekHrs, Length: 157, dtype: float64

# %%
df["Country"].value_counts()
# Out:
# United States       12469
# India                8403
# United Kingdom       3896
# Germany              3890
# Canada               2191
#                     ...
# North Korea             1
# Lesotho                 1
# Marshall Islands        1
# Liechtenstein           1
# Mali                    1
# Name: Country, Length: 183, dtype: int64

# %%
df.groupby("Country").get_group("Ethiopia")["Country"]
# Out:
# Respondent
# 58339    Ethiopia
# 18005    Ethiopia
# 14315    Ethiopia
# 59966    Ethiopia
# 55498    Ethiopia
# 30903    Ethiopia
# 10338    Ethiopia
# 10846    Ethiopia
# 13352    Ethiopia
# 15042    Ethiopia
# 55481    Ethiopia
# 10296    Ethiopia
# 55499    Ethiopia
# 22551    Ethiopia
# 50325    Ethiopia
# 9883     Ethiopia
# 16291    Ethiopia
# 717      Ethiopia
# 7225     Ethiopia
# 9680     Ethiopia
# 11133    Ethiopia
# 14144    Ethiopia
# 16019    Ethiopia
# 16244    Ethiopia
# 18597    Ethiopia
# 20845    Ethiopia
# 23481    Ethiopia
# 27309    Ethiopia
# 29597    Ethiopia
# 31276    Ethiopia
# 32410    Ethiopia
# 38886    Ethiopia
# 39165    Ethiopia
# 42087    Ethiopia
# 42153    Ethiopia
# 42413    Ethiopia
# 42426    Ethiopia
# 42841    Ethiopia
# 43983    Ethiopia
# 45536    Ethiopia
# 47064    Ethiopia
# 50360    Ethiopia
# 50585    Ethiopia
# 55682    Ethiopia
# 57164    Ethiopia
# 57519    Ethiopia
# 58053    Ethiopia
# 58091    Ethiopia
# 58507    Ethiopia
# ...

# %%
df.groupby("Country")["WorkWeekHrs"].value_counts(normalize=True)["Ethiopia"]
# Out:
# WorkWeekHrs
# 40.0    0.45
# 70.0    0.10
# 4.0     0.05
# 8.0     0.05
# 13.0    0.05
# 25.0    0.05
# 28.0    0.05
# 30.0    0.05
# 48.0    0.05
# 56.0    0.05
# 84.0    0.05
# Name: WorkWeekHrs, dtype: float64

# %%
df.groupby("Country")["ConvertedComp"].median()["Ethiopia"]
# Out:
# 3756.0

# %%
df.groupby("Country")["ConvertedComp"].agg(["median", "mean"])
# Out:
#                                        median           mean
# Country
# Afghanistan                           15163.5  148290.125000
# Albania                               15900.0   25611.000000
# Algeria                                9432.0   10362.812500
# Andorra                               88640.0   88640.000000
# Angola                                 5292.0    5292.000000
# ...                                       ...            ...
# Venezuela, Bolivarian Republic of...   3600.0    6280.611111
# Viet Nam                              10344.0   28342.605769
# Yemen                                 36000.0   36000.000000
# Zambia                                 5452.0   17506.400000
# Zimbabwe                               7200.0   26338.181818
#
# [183 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq', 'CompTotal',
#        'ConvertedComp', 'Country', 'CurrencyDesc', 'CurrencySymbol',
#        'DatabaseDesireNextYear', 'DatabaseWorkedWith', 'DevType', 'EdLevel',
#        'Employment', 'Ethnicity', 'Gender', 'JobFactors', 'JobSat', 'JobSeek',
#        'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
df.groupby("Country")["LanguageWorkedWith"].apply(lambda x: x.str.contains("Python").sum())
# Out:
# Country
# Afghanistan                              11
# Albania                                  13
# Algeria                                  40
# Andorra                                   3
# Angola                                    1
#                                        ...
# Venezuela, Bolivarian Republic of...     29
# Viet Nam                                102
# Yemen                                     1
# Zambia                                    4
# Zimbabwe                                 13
# Name: LanguageWorkedWith, Length: 183, dtype: int64

# %%
country_respondents = df["Country"].value_counts()
country_respondents
# Out:
# United States       12469
# India                8403
# United Kingdom       3896
# Germany              3890
# Canada               2191
#                     ...
# North Korea             1
# Lesotho                 1
# Marshall Islands        1
# Liechtenstein           1
# Mali                    1
# Name: Country, Length: 183, dtype: int64

# %%
country_uses_python = df.groupby("Country")["LanguageWorkedWith"].apply(lambda x: x.str.contains("Python").sum())
country_uses_python
# Out:
# Country
# Afghanistan                              11
# Albania                                  13
# Algeria                                  40
# Andorra                                   3
# Angola                                    1
#                                        ...
# Venezuela, Bolivarian Republic of...     29
# Viet Nam                                102
# Yemen                                     1
# Zambia                                    4
# Zimbabwe                                 13
# Name: LanguageWorkedWith, Length: 183, dtype: int64

# %%
python_df = pd.concat([country_respondents, country_uses_python], axis="columns", sort=False)
python_df
# Out:
#                   Country  LanguageWorkedWith
# United States       12469                5964
# India                8403                2670
# United Kingdom       3896                1621
# Germany              3890                1712
# Canada               2191                1011
# ...                   ...                 ...
# North Korea             1                   0
# Lesotho                 1                   0
# Marshall Islands        1                   0
# Liechtenstein           1                   0
# Mali                    1                   0
#
# [183 rows x 2 columns]

# %%
python_df.rename(columns={"Country": "NumRespondents", "LanguageWorkedWith": "NumKnowsPython"}, inplace=True)
python_df
# Out:
#                   NumRespondents  NumKnowsPython
# United States              12469            5964
# India                       8403            2670
# United Kingdom              3896            1621
# Germany                     3890            1712
# Canada                      2191            1011
# ...                          ...             ...
# North Korea                    1               0
# Lesotho                        1               0
# Marshall Islands               1               0
# Liechtenstein                  1               0
# Mali                           1               0
#
# [183 rows x 2 columns]

# %%
python_df["PctKnowsPython"] = (python_df["NumKnowsPython"]/python_df["NumRespondents"])*100
python_df
# Out:
#                   NumRespondents  NumKnowsPython  PctKnowsPython
# United States              12469            5964        32.20339
# India                       8403            2670        32.20339
# United Kingdom              3896            1621        32.20339
# Germany                     3890            1712        32.20339
# Canada                      2191            1011        32.20339
# ...                          ...             ...             ...
# North Korea                    1               0        32.20339
# Lesotho                        1               0        32.20339
# Marshall Islands               1               0        32.20339
# Liechtenstein                  1               0        32.20339
# Mali                           1               0        32.20339
#
# [183 rows x 3 columns]

# %%
python_df.loc["Ethiopia"]
# Out:
# NumRespondents    59.00000
# NumKnowsPython    19.00000
# PctKnowsPython    32.20339
# Name: Ethiopia, dtype: float64

# %% [markdown]
# # 9. Cleaning Data - Casting Datatypes and Handling Missing Values

# %%
df["YearsCode"].astype("float").mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-3e3c44e3da67> in <module>
# ----> 1 df["YearsCode"].astype("float").mean()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ...

# %%
df["YearsCode"].unique()
# Out:
# array(['36', '7', '4', '15', '6', '17', '8', '10', '35', '5', '37', '19',
#        '9', '22', '30', '23', '20', '2', 'Less than 1 year', '3', '13',
#        '25', '16', '43', '11', '38', '33', nan, '24', '21', '12', '40',
#        '27', '50', '46', '14', '18', '28', '32', '44', '26', '42', '31',
#        '34', '29', '1', '39', '41', '45', 'More than 50 years', '47',
#        '49', '48'], dtype=object)

# %%
df.replace({"Less than 1 year": 0, "More than 50 years": 51}, inplace=True)
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN      Yes   NaN
# 64867                                                     NaN      Yes   NaN
# 64898                                                     NaN      Yes   NaN
# 64925                                                     NaN      Yes   NaN
# 65112                                                     NaN      Yes   NaN
#
# ...

# %%
df["YearsCode"].astype(float).mean()
# Out:
# 12.709052770265584

# %% [markdown]
# # 10. Working with Dates and Time Series Data

# %%
df = pd.read_csv("data/ETH_1H.csv")

# %%
df.head()
# Out:
#    Unix Timestamp                 Date  Symbol    Open    High     Low  \
# 0   1586995200000  2020-04-16 00:00:00  ETHUSD  152.94  152.94  150.39
# 1   1586991600000  2020-04-15 23:00:00  ETHUSD  155.81  155.81  151.39
# 2   1586988000000  2020-04-15 22:00:00  ETHUSD  157.18  157.30  155.32
# 3   1586984400000  2020-04-15 21:00:00  ETHUSD  158.04  158.31  157.16
# 4   1586980800000  2020-04-15 20:00:00  ETHUSD  157.10  158.10  156.87
#
#     Close       Volume
# 0  150.39   650.188125
# 1  152.94  4277.567299
# 2  155.81   106.337279
# 3  157.18    55.244131
# 4  158.04   144.262622

# %%
df.loc[0, "Date"].day_name()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-daac2243067c> in <module>
# ----> 1 df.loc[0, "Date"].day_name()
#
# AttributeError: 'str' object has no attribute 'day_name'

# %%
df["Date"] = pd.to_datetime(df["Date"], format="%Y-%m-%d %H:%M:%S")

# %%
df.loc[0, "Date"].day_name()
# Out:
# 'Thursday'

# %%
df["Date"].dt.day_name()
# Out:
# 0         Thursday
# 1        Wednesday
# 2        Wednesday
# 3        Wednesday
# 4        Wednesday
#            ...
# 34492       Monday
# 34493       Monday
# 34494       Monday
# 34495       Monday
# 34496       Monday
# Name: Date, Length: 34497, dtype: object

# %%
df["DayOfWeek"] = df["Date"].dt.day_name()
df
# Out:
#        Unix Timestamp                Date  Symbol    Open    High     Low  \
# 0       1586995200000 2020-04-16 00:00:00  ETHUSD  152.94  152.94  150.39
# 1       1586991600000 2020-04-15 23:00:00  ETHUSD  155.81  155.81  151.39
# 2       1586988000000 2020-04-15 22:00:00  ETHUSD  157.18  157.30  155.32
# 3       1586984400000 2020-04-15 21:00:00  ETHUSD  158.04  158.31  157.16
# 4       1586980800000 2020-04-15 20:00:00  ETHUSD  157.10  158.10  156.87
# ...               ...                 ...     ...     ...     ...     ...
# 34492      1462813200 2016-05-09 17:00:00  ETHUSD    9.83    9.83    9.48
# 34493      1462809600 2016-05-09 16:00:00  ETHUSD    9.99    9.99    9.79
# 34494      1462806000 2016-05-09 15:00:00  ETHUSD   10.00   10.00    9.99
# 34495      1462802400 2016-05-09 14:00:00  ETHUSD    9.55   10.00    9.55
# 34496      1462798800 2016-05-09 13:00:00  ETHUSD    0.00   12.00    0.00
#
#         Close       Volume  DayOfWeek
# 0      150.39   650.188125   Thursday
# ...

# %%
df["Date"].min()
# Out:
# Timestamp('2016-05-09 13:00:00')

# %%
df["Date"].max()
# Out:
# Timestamp('2020-04-16 00:00:00')

# %%
df["Date"].max() - df["Date"].min()
# Out:
# Timedelta('1437 days 11:00:00')

# %%
filt = (df["Date"] >= pd.to_datetime("2019")) & (df["Date"] < pd.to_datetime("2020")) 
df[filt]
# Out:
#        Unix Timestamp                Date  Symbol    Open    High     Low  \
# 2545    1577833200000 2019-12-31 23:00:00  ETHUSD  128.68  128.85  127.82
# 2546    1577829600000 2019-12-31 22:00:00  ETHUSD  128.40  128.93  127.77
# 2547    1577826000000 2019-12-31 21:00:00  ETHUSD  127.87  128.41  127.81
# 2548    1577822400000 2019-12-31 20:00:00  ETHUSD  127.86  128.30  127.86
# 2549    1577818800000 2019-12-31 19:00:00  ETHUSD  128.78  128.78  127.86
# ...               ...                 ...     ...     ...     ...     ...
# 11297   1546315200000 2019-01-01 04:00:00  ETHUSD  130.83  133.75  130.83
# 11298   1546311600000 2019-01-01 03:00:00  ETHUSD  129.79  131.00  129.79
# 11299   1546308000000 2019-01-01 02:00:00  ETHUSD  130.98  130.98  129.25
# 11300   1546304400000 2019-01-01 01:00:00  ETHUSD  131.10  131.10  128.72
# 11301   1546300800000 2019-01-01 00:00:00  ETHUSD  130.80  131.70  130.00
#
#         Close       Volume DayOfWeek
# 2545   128.84   857.650259   Tuesday
# ...

# %%
df.set_index("Date", inplace=True)

# %%
df.loc["2020"]
# Out:
#                      Unix Timestamp  Symbol    Open    High     Low   Close  \
# Date
# 2020-04-16 00:00:00   1586995200000  ETHUSD  152.94  152.94  150.39  150.39
# 2020-04-15 23:00:00   1586991600000  ETHUSD  155.81  155.81  151.39  152.94
# 2020-04-15 22:00:00   1586988000000  ETHUSD  157.18  157.30  155.32  155.81
# 2020-04-15 21:00:00   1586984400000  ETHUSD  158.04  158.31  157.16  157.18
# 2020-04-15 20:00:00   1586980800000  ETHUSD  157.10  158.10  156.87  158.04
# ...                             ...     ...     ...     ...     ...     ...
# 2020-01-01 04:00:00   1577851200000  ETHUSD  129.83  129.96  129.13  129.54
# 2020-01-01 03:00:00   1577847600000  ETHUSD  130.25  130.30  129.42  129.83
# 2020-01-01 02:00:00   1577844000000  ETHUSD  129.95  130.58  129.95  130.25
# 2020-01-01 01:00:00   1577840400000  ETHUSD  128.11  130.01  128.11  129.95
# 2020-01-01 00:00:00   1577836800000  ETHUSD  128.84  128.84  128.07  128.11
#
#                           Volume  DayOfWeek
# ...

# %%
df.loc["2020-02": "2020-01"]["Close"].mean()
# Out:
# 195.22266666666675

# %%
df.loc["2020-01-01"]["High"].max()
# Out:
# 132.57

# %%
highs = df["High"].resample("D").max()
highs["2020-01-01"]
# Out:
# 132.57

# %%
# %matplotlib inline

# %%
highs.plot()

# %%
df.resample("W").mean()
# Out:
#             Unix Timestamp        Open        High         Low       Close  \
# Date
# 2016-05-15    1.463076e+09   10.140387   10.310516   10.052387   10.205290
# 2016-05-22    1.463657e+09   13.042262   13.144048   12.965179   13.066964
# 2016-05-29    1.464262e+09   12.481012   12.555536   12.385357   12.471012
# 2016-06-05    1.464867e+09   13.586369   13.651667   13.542202   13.594583
# 2016-06-12    1.465472e+09   14.287500   14.326190   14.260179   14.297798
# ...                    ...         ...         ...         ...         ...
# 2020-03-22    1.584617e+12  124.640952  126.387917  122.802262  124.636012
# 2020-03-29    1.585222e+12  133.274762  134.287857  132.255714  133.285893
# 2020-04-05    1.585827e+12  137.517083  138.314583  136.791310  137.627440
# 2020-04-12    1.586432e+12  163.601548  164.731071  162.422560  163.693929
# 2020-04-19    1.586866e+12  156.890137  157.744384  155.952055  156.778219
#
#                  Volume
# Date
# 2016-05-15    70.896402
# ...

# %%
df.resample("W").agg({"Close": "mean", "High": "max", "Low": "min", "Volume": "sum"})
# Out:
#                  Close    High     Low         Volume
# Date
# 2016-05-15   10.205290   12.00    0.00   10988.942273
# 2016-05-22   13.066964   14.77   10.06   40673.495362
# 2016-05-29   12.471012   14.43   10.41   58051.809091
# 2016-06-05   13.594583   16.05   12.41   47351.544496
# 2016-06-12   14.297798   15.75   13.83   52002.171838
# ...                ...     ...     ...            ...
# 2020-03-22  124.636012  153.17  100.70  439980.283707
# 2020-03-29  133.285893  144.14  119.17  230941.584515
# 2020-04-05  137.627440  150.32  124.09  151022.864981
# 2020-04-12  163.693929  176.74  142.87  204715.937994
# 2020-04-19  156.778219  162.15  150.12   50776.889638
#
# [206 rows x 4 columns]

# %% [markdown]
# # 11. Reading/Writing Data to Different Sources

# %%
filt = (df["Country"] == "Ethiopia")
ethio_df = df[filt]
ethio_df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 717         I used to be a developer by profession, but no...       No  22.0
# 7225                              I code primarily as a hobby      Yes  70.0
# 9680                           I am a developer by profession      Yes   NaN
# 9883        I am not primarily a developer, but I write co...      Yes   NaN
# 10296                          I am a developer by profession      Yes  22.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp   Country  \
# Respondent
# 717                20      NaN        NaN            NaN  Ethiopia
# 7225               33      NaN        NaN            NaN  Ethiopia
# 9680               14      NaN        NaN            NaN  Ethiopia
# 9883               21  Monthly     6000.0         2256.0  Ethiopia
# 10296              17  Monthly     8310.0         3120.0  Ethiopia
#
# ...

# %%
ethio_df.to_csv("data/modified.csv")

# %%
ethio_df.to_excel("data/modified.xlsx")

# %%
modified_df = pd.read_excel("data/modified.xlsx", index_col="Respondent")
modified_df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 717         I used to be a developer by profession, but no...       No  22.0
# 7225                              I code primarily as a hobby      Yes  70.0
# 9680                           I am a developer by profession      Yes   NaN
# 9883        I am not primarily a developer, but I write co...      Yes   NaN
# 10296                          I am a developer by profession      Yes  22.0
#
#             Age1stCode CompFreq  CompTotal  ConvertedComp   Country  \
# Respondent
# 717               20.0      NaN        NaN            NaN  Ethiopia
# 7225              33.0      NaN        NaN            NaN  Ethiopia
# 9680              14.0      NaN        NaN            NaN  Ethiopia
# 9883              21.0  Monthly     6000.0         2256.0  Ethiopia
# 10296             17.0  Monthly     8310.0         3120.0  Ethiopia
#
# ...

# %%
ethio_df.to_json("data/modified.json")

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('mysql+pymysql://yony:password@localhost:3306/sample_db')

# %%
ethio_df.to_sql("sample_table", engine, if_exists="replace")

# %%
help(pd.read_sql)
# Out:
# Help on function read_sql in module pandas.io.sql:
#
# read_sql(sql, con, index_col=None, coerce_float=True, params=None, parse_dates=None, columns=None, chunksize=None)
#     Read SQL query or database table into a DataFrame.
#
#     This function is a convenience wrapper around ``read_sql_table`` and
#     ``read_sql_query`` (for backward compatibility). It will delegate
#     to the specific function depending on the provided input. A SQL query
#     will be routed to ``read_sql_query``, while a database table name will
#     be routed to ``read_sql_table``. Note that the delegated function might
#     have more specific notes about their functionality not listed here.
#
#     Parameters
#     ----------
#     sql : str or SQLAlchemy Selectable (select or text object)
#         SQL query to be executed or a table name.
#     con : SQLAlchemy connectable (engine/connection) or database str URI
#         or DBAPI2 connection (fallback mode)'
#
# ...

# %%
sql_df = pd.read_sql("sample_table", engine, index_col="Respondent")
sql_df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 717         I used to be a developer by profession, but no...       No  22.0
# 7225                              I code primarily as a hobby      Yes  70.0
# 9680                           I am a developer by profession      Yes   NaN
# 9883        I am not primarily a developer, but I write co...      Yes   NaN
# 10296                          I am a developer by profession      Yes  22.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp   Country  \
# Respondent
# 717                20     None        NaN            NaN  Ethiopia
# 7225               33     None        NaN            NaN  Ethiopia
# 9680               14     None        NaN            NaN  Ethiopia
# 9883               21  Monthly     6000.0         2256.0  Ethiopia
# 10296              17  Monthly     8310.0         3120.0  Ethiopia
#
# ...

# %%
sql_df = pd.read_sql_query("SELECT * FROM SAMPLE_TABLE", engine, index_col="Responent")
sql_df.
